# %% [markdown]
# Выведем результат обучения модели.

# %%
import torch
import homeworkCV_2.src.initial_training as it

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
it.train_model(batch_size=132, epochs=2, lr=0.001, seed=42, device=device)
# Out:
# Epoch 1 of 2
# 379it [00:18, 20.26it/s]
# Train Loss: 0.0123, Train Acc: 40.84
# 76it [00:02, 35.84it/s]
# Test Loss: 0.0100, Test Acc: 52.97
#
# Epoch 2 of 2
# 379it [00:18, 20.20it/s]
# Train Loss: 0.0105, Train Acc: 49.71
# 76it [00:02, 35.88it/s]
# Test Loss: 0.0090, Test Acc: 58.28
# End. Final accuracy 58.25
